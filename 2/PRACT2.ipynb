# %%
import pandas as pd
import numpy as np
import matplotlib as plot
import seaborn as sns

# %%
df=pd.read_csv("student_performance_prediction.csv")

# %%
df
# Out:
#       Student ID  Study Hours per Week  Attendance Rate  Previous Grades  \
# 0         S00001                  12.5              NaN             75.0
# 1         S00002                   9.3             95.3             60.6
# 2         S00003                  13.2              NaN             64.0
# 3         S00004                  17.6             76.8             62.4
# 4         S00005                   8.8             89.3             72.7
# ...          ...                   ...              ...              ...
# 39995     S39996                  15.6             93.8             51.4
# 39996     S39997                  11.3             66.4             64.2
# 39997     S39998                  13.1             65.6             38.1
# 39998     S39999                  14.1             74.9              NaN
# 39999     S40000                  11.8             55.1             68.5
#
#       Participation in Extracurricular Activities Parent Education Level  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40000 entries, 0 to 39999
# Data columns (total 7 columns):
#  #   Column                                       Non-Null Count  Dtype
# ---  ------                                       --------------  -----
#  0   Student ID                                   40000 non-null  object
#  1   Study Hours per Week                         38005 non-null  float64
#  2   Attendance Rate                              38008 non-null  float64
#  3   Previous Grades                              38006 non-null  float64
#  4   Participation in Extracurricular Activities  38000 non-null  object
#  5   Parent Education Level                       38000 non-null  object
#  6   Passed                                       38000 non-null  object
# dtypes: float64(3), object(4)
# memory usage: 2.1+ MB

# %%
df.count()
# Out:
# Student ID                                     40000
# Study Hours per Week                           38005
# Attendance Rate                                38008
# Previous Grades                                38006
# Participation in Extracurricular Activities    38000
# Parent Education Level                         38000
# Passed                                         38000
# dtype: int64

# %%
df.head()
# Out:
#   Student ID  Study Hours per Week  Attendance Rate  Previous Grades  \
# 0     S00001                  12.5              NaN             75.0
# 1     S00002                   9.3             95.3             60.6
# 2     S00003                  13.2              NaN             64.0
# 3     S00004                  17.6             76.8             62.4
# 4     S00005                   8.8             89.3             72.7
#
#   Participation in Extracurricular Activities Parent Education Level Passed
# 0                                         Yes                 Master    Yes
# 1                                          No            High School     No
# 2                                          No              Associate     No
# 3                                         Yes               Bachelor     No
# 4                                          No                 Master     No

# %%
df.tail(10)
# Out:
#       Student ID  Study Hours per Week  Attendance Rate  Previous Grades  \
# 39990     S39991                  19.1              NaN             94.9
# 39991     S39992                  15.0             52.1             70.4
# 39992     S39993                  10.8             46.3             73.5
# 39993     S39994                   7.0             86.3             65.5
# 39994     S39995                   5.1             92.1             46.1
# 39995     S39996                  15.6             93.8             51.4
# 39996     S39997                  11.3             66.4             64.2
# 39997     S39998                  13.1             65.6             38.1
# 39998     S39999                  14.1             74.9              NaN
# 39999     S40000                  11.8             55.1             68.5
#
#       Participation in Extracurricular Activities Parent Education Level  \
# 39990                                          No                    NaN
# ...

# %%
df.isnull().sum()
# Out:
# Student ID                                        0
# Study Hours per Week                           1995
# Attendance Rate                                1992
# Previous Grades                                1994
# Participation in Extracurricular Activities    2000
# Parent Education Level                         2000
# Passed                                         2000
# dtype: int64

# %%
df=df.drop(['Participation in Extracurricular Activities'],axis=1)

# %%
df.describe()
# Out:
#        Study Hours per Week  Attendance Rate  Previous Grades
# count          38005.000000     38008.000000     38006.000000
# mean               9.962744        75.276323        65.440107
# std                5.031154        20.393418        16.503119
# min              -12.300000       -14.300000         8.300000
# 25%                6.600000        61.600000        55.100000
# 50%               10.000000        75.300000        65.200000
# 75%               13.400000        88.800000        75.200000
# max               32.400000       150.200000       200.000000

# %%
df.shape
# Out:
# (40000, 6)

# %%
df.fillna(0)
# Out:
#       Student ID  Study Hours per Week  Attendance Rate  Previous Grades  \
# 0         S00001                  12.5              0.0             75.0
# 1         S00002                   9.3             95.3             60.6
# 2         S00003                  13.2              0.0             64.0
# 3         S00004                  17.6             76.8             62.4
# 4         S00005                   8.8             89.3             72.7
# ...          ...                   ...              ...              ...
# 39995     S39996                  15.6             93.8             51.4
# 39996     S39997                  11.3             66.4             64.2
# 39997     S39998                  13.1             65.6             38.1
# 39998     S39999                  14.1             74.9              0.0
# 39999     S40000                  11.8             55.1             68.5
#
#       Parent Education Level Passed
# 0                     Master    Yes
# ...

# %%
df['Attendance Rate']=df['Attendance Rate'].fillna(np.mean(df['Attendance Rate']))

# %%
df
# Out:
#       Student ID  Study Hours per Week  Attendance Rate  Previous Grades  \
# 0         S00001                  12.5        75.276323             75.0
# 1         S00002                   9.3        95.300000             60.6
# 2         S00003                  13.2        75.276323             64.0
# 3         S00004                  17.6        76.800000             62.4
# 4         S00005                   8.8        89.300000             72.7
# ...          ...                   ...              ...              ...
# 39995     S39996                  15.6        93.800000             51.4
# 39996     S39997                  11.3        66.400000             64.2
# 39997     S39998                  13.1        65.600000             38.1
# 39998     S39999                  14.1        74.900000              NaN
# 39999     S40000                  11.8        55.100000             68.5
#
#       Parent Education Level Passed
# 0                     Master    Yes
# ...

# %%
df['Study Hours per Week']=df['Study Hours per Week'].fillna(np.mean(df['Study Hours per Week']))

# %%
df['Previous Grades']=df['Previous Grades'].fillna(df['Previous Grades'].mode())

# %%
df.isnull().sum()
# Out:
# Student ID                   0
# Study Hours per Week         0
# Attendance Rate              0
# Previous Grades           1994
# Parent Education Level    2000
# Passed                    2000
# dtype: int64

# %%
df.hist()
# Out:
# array([[<Axes: title={'center': 'Study Hours per Week'}>,
#         <Axes: title={'center': 'Attendance Rate'}>],
#        [<Axes: title={'center': 'Previous Grades'}>, <Axes: >]],
#       dtype=object)
